# %% [markdown]
# Problem Statement - Food Nutrition
#
# Intro to Python

# %%
#Import all the necessary modules
#Import all the necessary modules
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Set the working directory

# %%
#os.getcwd()
#import os
#os.getcwd()

# %%
#os.chdir('D:\\Mentors\\Python\\Week1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shohel Noor\\Box Sync\\Python2\\Doubt Clearing Week 1 and 2'

# %% [markdown]
# # Import Excel file

# %% [markdown]
# Load the Data file into Python DataFrame using pandas read_excel method

# %% [markdown]
# The csv that we are going to load contains the unicode format data. We will use an additional encoding parameter which will allow pandas to load the csv.

# %%
data_df = pd.read_excel('Food Nutrition.xlsx')

# %%
 data_df.drop('NDB_No', axis=1)
# Out:
#                                              Shrt_Desc  Water_(g)  Energ_Kcal  \
# 0                                     BUTTER,WITH SALT      15.87         717
# 1                               BUTTER,WHIPPED,W/ SALT      16.72         718
# 2                                 BUTTER OIL,ANHYDROUS       0.24         876
# 3                                          CHEESE,BLUE      42.41         353
# 4                                         CHEESE,BRICK      41.11         371
# ..                                                 ...        ...         ...
# 595  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79          66
# 596  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25         522
# 597  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16         127
# 598  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81         128
# 599  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54          66
#
#      Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 0           0.85          81.11     2.11            0.06           0.0
# 1           0.49          78.30     1.62            2.87           0.0
# 2           0.28          99.48     0.00            0.00           0.0
# 3          21.40          28.74      NaN            2.34           0.0
# 4          23.24            NaN     3.18            2.79           0.0
# ..           ...            ...      ...             ...           ...
# 595         1.36           3.70     0.38            6.77           0.0
# 596        10.89          28.87     3.26           54.73           0.0
# 597         2.64           6.89     0.79           13.52           0.0
# 598         3.13           6.98     0.88           13.21           0.0
# 599         1.61           3.59     0.66            6.70           0.0
#
#      Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  \
# 0             0.06            24       0.02               2               24
# 1             0.06            23       0.05               1               24
# 2             0.00             4       0.00               0                3
# 3             0.50           528       0.31              23              387
# 4             0.51           674       0.43              24              451
# ..             ...           ...        ...             ...              ...
# 595           6.90            53       1.18               4               28
# 596          54.73           410       9.47              32              221
# 597          13.52            99       2.30               8               54
# 598          13.10           134       2.30              10               96
# 599           6.70            69       1.18               5               49
#
#      Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  Manganese_(mg)  \
# 0                24          643       0.09       0.000           0.000
# 1                41          583       0.05       0.010           0.001
# 2                 5            2       0.01       0.001           0.000
# 3               256         1146       2.66       0.040           0.009
# 4               136          560       2.60       0.024           0.012
# ..              ...          ...        ...         ...             ...
# 595              69           16       0.49       0.059           0.003
# 596             552          126       3.94       0.473           0.026
# 597             134           31       0.96       0.115           0.006
# 598             138           56       0.96       0.096           0.032
# 599              71           29       0.49       0.049           0.016
#
#      Selenium_(µg)
# 0              1.0
# 1              0.0
# 2              0.0
# 3             14.5
# 4             14.5
# ..             ...
# 595            1.2
# 596           11.6
# 597            2.8
# 598            2.7
# 599            1.4
#
# [600 rows x 19 columns]

# %%
data_df
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 3      1004                                        CHEESE,BLUE      42.41
# 4      1005                                       CHEESE,BRICK      41.11
# ..      ...                                                ...        ...
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0           717         0.85          81.11     2.11            0.06
# 1           718         0.49          78.30     1.62            2.87
# 2           876         0.28          99.48     0.00            0.00
# 3           353        21.40          28.74      NaN            2.34
# 4           371        23.24            NaN     3.18            2.79
# ..          ...          ...            ...      ...             ...
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# 0             0.0           0.06            24       0.02               2
# 1             0.0           0.06            23       0.05               1
# 2             0.0           0.00             4       0.00               0
# 3             0.0           0.50           528       0.31              23
# 4             0.0           0.51           674       0.43              24
# ..            ...            ...           ...        ...             ...
# 595           0.0           6.90            53       1.18               4
# 596           0.0          54.73           410       9.47              32
# 597           0.0          13.52            99       2.30               8
# 598           0.0          13.10           134       2.30              10
# 599           0.0           6.70            69       1.18               5
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 0                 24              24          643       0.09       0.000
# 1                 24              41          583       0.05       0.010
# 2                  3               5            2       0.01       0.001
# 3                387             256         1146       2.66       0.040
# 4                451             136          560       2.60       0.024
# ..               ...             ...          ...        ...         ...
# 595               28              69           16       0.49       0.059
# 596              221             552          126       3.94       0.473
# 597               54             134           31       0.96       0.115
# 598               96             138           56       0.96       0.096
# 599               49              71           29       0.49       0.049
#
#      Manganese_(mg)  Selenium_(µg)
# 0             0.000            1.0
# 1             0.001            0.0
# 2             0.000            0.0
# 3             0.009           14.5
# 4             0.012           14.5
# ..              ...            ...
# 595           0.003            1.2
# 596           0.026           11.6
# 597           0.006            2.8
# 598           0.032            2.7
# 599           0.016            1.4
#
# [600 rows x 20 columns]

# %% [markdown]
# # View Top 10 rows

# %% [markdown]
# head function is used to view the top records. The number records to be view need to be  given in the parenthesis.

# %%
data_df.head(20)
# Out:
#     NDB_No                                         Shrt_Desc  Water_(g)  \
# 0     1001                                  BUTTER,WITH SALT      15.87
# 1     1002                            BUTTER,WHIPPED,W/ SALT      16.72
# 2     1003                              BUTTER OIL,ANHYDROUS       0.24
# 3     1004                                       CHEESE,BLUE      42.41
# 4     1005                                      CHEESE,BRICK      41.11
# 5     1006                                       CHEESE,BRIE      48.42
# 6     1007                                  CHEESE,CAMEMBERT      51.80
# 7     1008                                    CHEESE,CARAWAY      39.28
# 8     1009                                    CHEESE,CHEDDAR      37.02
# 9     1010                                   CHEESE,CHESHIRE      37.65
# 10    1011                                      CHEESE,COLBY      38.20
# 11    1012               CHEESE,COTTAGE,CRMD,LRG OR SML CURD      79.79
# 12    1013                       CHEESE,COTTAGE,CRMD,W/FRUIT      79.64
# 13    1014  CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD      81.01
# 14    1015                  CHEESE,COTTAGE,LOWFAT,2% MILKFAT      81.24
# 15    1016                  CHEESE,COTTAGE,LOWFAT,1% MILKFAT      82.48
# 16    1017                                      CHEESE,CREAM      52.62
# 17    1018                                       CHEESE,EDAM      41.56
# 18    1019                                       CHEESE,FETA      55.22
# 19    1020                                    CHEESE,FONTINA      37.92
#
#     Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0          717         0.85          81.11     2.11            0.06
# 1          718         0.49          78.30     1.62            2.87
# 2          876         0.28          99.48     0.00            0.00
# 3          353        21.40          28.74      NaN            2.34
# 4          371        23.24            NaN     3.18            2.79
# 5          334        20.75          27.68     2.70            0.45
# 6          300        19.80          24.26     3.68            0.46
# 7          376        25.18          29.20     3.28            3.06
# 8          404        22.87          33.31     3.71            3.09
# 9          387        23.37          30.60     3.60            4.78
# 10         394        23.76          32.11     3.36            2.57
# 11          98        11.12           4.30     1.41            3.38
# 12          97        10.69           3.85     1.20            4.61
# 13          72        10.34           0.29     1.71            6.66
# 14          81        10.45           2.27     1.27            4.76
# 15          72        12.39           1.02     1.39            2.72
# 16         350         6.15          34.44     1.27            5.52
# 17         357        24.99          27.80     4.22            1.43
# 18         264        14.21          21.28     5.20            4.09
# 19         389        25.60          31.14     3.79            1.55
#
#     Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# 0            0.0           0.06            24       0.02               2
# 1            0.0           0.06            23       0.05               1
# 2            0.0           0.00             4       0.00               0
# 3            0.0           0.50           528       0.31              23
# 4            0.0           0.51           674       0.43              24
# 5            0.0           0.45           184       0.50              20
# 6            0.0           0.46           388       0.33              20
# 7            0.0           0.00           673       0.64              22
# 8            0.0           0.48           710       0.14              27
# 9            0.0           0.00           643       0.21              21
# 10           0.0           0.52           685       0.76              26
# 11           0.0           2.67            83       0.07               8
# 12           0.2           2.38            53       0.16               7
# 13           0.0           1.85            86       0.15              11
# 14           0.0           4.00           111       0.13               9
# 15           0.0           2.72            61       0.14               5
# 16           0.0           3.76            97       0.11               9
# 17           0.0           1.43           731       0.44              30
# 18           0.0           4.09           493       0.65              19
# 19           0.0           1.55           550       0.23              14
#
#     Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 0                24              24          643       0.09       0.000
# 1                24              41          583       0.05       0.010
# 2                 3               5            2       0.01       0.001
# 3               387             256         1146       2.66       0.040
# 4               451             136          560       2.60       0.024
# 5               188             152          629       2.38       0.019
# 6               347             187          842       2.38       0.021
# 7               490              93          690       2.94       0.024
# 8               455              76          653       3.64       0.030
# 9               464              95          700       2.79       0.042
# 10              457             127          604       3.07       0.042
# 11              159             104          364       0.40       0.029
# 12              113              90          344       0.33       0.040
# 13              190             137          372       0.47       0.030
# 14              150             125          308       0.51       0.033
# 15              134              86          406       0.38       0.028
# 16              107             132          314       0.50       0.018
# 17              536             188          812       3.75       0.036
# 18              337              62          917       2.88       0.032
# 19              346              64          800       3.50       0.025
#
#     Manganese_(mg)  Selenium_(µg)
# 0            0.000            1.0
# 1            0.001            0.0
# 2            0.000            0.0
# 3            0.009           14.5
# 4            0.012           14.5
# 5            0.034           14.5
# 6            0.038           14.5
# 7            0.021           14.5
# 8            0.027           28.5
# 9            0.012           14.5
# 10           0.012           14.5
# 11           0.002            9.7
# 12           0.003            7.7
# 13           0.022            9.4
# 14           0.015           11.9
# 15           0.003            9.0
# 16           0.011            8.6
# 17           0.011           14.5
# 18           0.028           15.0
# 19           0.014           14.5

# %% [markdown]
# # View Last 20 records

# %% [markdown]
# tail function is used to view the last records. The number records to be view need to be given in the parenthesis.

# %%
data_df.tail(20)
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 580    3934                   BABYFOOD,CORN & SWT POTATOES,STR      82.62
# 581    3935  INF FORM, ABBO NUTR, SIMIL, ALIMENT, ADVAN, RT...      87.32
# 582    3936  INF FORMULA,PBM PRODUC,STO BRA,RTF (FORMERLY W...      88.10
# 583    3937  INF FORM,PBM PROD,STORE BRAND,LC,NOT REC (FORM...      76.00
# 584    3938           INF FORMULA,PBM PRODUCTS,STORE BRAND,PDR       2.00
# 585    3939       INF FORMULA,PBM PRODUCTS,STORE BRAND,SOY,RTF      88.00
# 586    3940  INF FORMU,PBM PRODU,STORE BR,SOY,LIQ CONC,NOT ...      76.00
# 587    3941       INF FORMULA,PBM PRODUCTS,STORE BRAND,SOY,PDR       2.00
# 588    3942  INF FORMULA, MEAD JOHNS, ENFAMI, AR LIPIL, RTF...      87.00
# 589    3943  INF FORMULA, MEA JOHNSO, ENFAMI, AR LIPIL, PDR...       3.00
# 590    3944    INF FORM,ABBOT NUT,SIMIL NEOSU,RTF,W/ ARA & DHA      87.00
# 591    3945  INF FORMULA, ABBOTT, SIMILAC, NEOSURE, PDR, W/...       2.25
# 592    3946  INF FORMULA, ABB NUTR, SIMI,SENS (LACT FRE) RT...      87.00
# 593    3947  INF FORMULA, ABB NUT,SIMIL,SENS,(LACT FR),LIQ ...      75.88
# 594    3948  INF FORMULA, ABB NUTR,SIMIL,SENS,(LACTO FR), P...       2.20
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 580          68         1.26           0.28     0.61           15.23
# 581          67         1.80           3.63     0.48            6.77
# 582          63         1.40           3.50     0.61            6.39
# 583         130         2.90           7.00     0.61           13.90
# 584         524        12.00          28.00     2.00           56.00
# 585          63         1.80           3.50     0.61            6.09
# 586         126         3.60           7.00     1.22           12.18
# 587         508        13.60          27.20     5.00           52.20
# 588          68         1.71           3.49     0.33            7.53
# 589         509        12.73          25.97     2.46           56.03
# 590          69         1.92           3.77     0.38            6.94
# 591         520        14.42          28.33     3.26           51.75
# 592          68         1.48           3.74     0.75            7.40
# 593         128         2.73           6.95     0.80           13.64
# 594         520        11.13          28.14     3.00           55.67
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# 580           1.8           4.00            18       0.31              10
# 581           0.0           4.40            69       1.18               5
# 582           0.0           6.40            41       1.18               5
# 583           0.0          13.90            83       2.36               9
# 584           0.0          56.00           331       9.50              36
# 585           0.0           6.10            59       1.18               7
# 586           0.0          12.18           118       2.36              14
# 587           0.0          52.20           453       9.10              51
# 588           0.0           6.44            53       1.23               5
# 589           0.0          56.03           397       9.16              41
# 590           0.0           6.90            72       1.23               6
# 591           0.0          52.02           541       9.26              46
# 592           0.0           7.40            58       1.24               3
# 593           0.0          13.78           108       2.32               8
# 594           0.0          55.67           436       9.33              30
# 595           0.0           6.90            53       1.18               4
# 596           0.0          54.73           410       9.47              32
# 597           0.0          13.52            99       2.30               8
# 598           0.0          13.10           134       2.30              10
# 599           0.0           6.70            69       1.18               5
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 580               29             154           14       0.19       0.051
# 581               49              77           29       0.49       0.049
# 582               28              55           14       0.53       0.046
# 583               55             109           29       1.06       0.092
# 584              221             441          118       3.90       0.370
# 585               41              69           18       0.53       0.046
# 586               82             138           36       1.06       0.092
# 587              317             528          151       3.80       0.355
# 588               36              74           27       0.68       0.051
# 589              269             550          204       5.09       0.382
# 590               42              97           23       0.82       0.082
# 591              319             731          170       6.18       0.618
# 592               39              74           21       0.52       0.060
# 593               72             138           39       0.97       0.062
# 594              293             557          158       3.91       0.451
# 595               28              69           16       0.49       0.059
# 596              221             552          126       3.94       0.473
# 597               54             134           31       0.96       0.115
# 598               96             138           56       0.96       0.096
# 599               49              71           29       0.49       0.049
#
#      Manganese_(mg)  Selenium_(µg)
# 580           0.000            1.1
# 581           0.006            1.2
# 582           0.677            1.4
# 583           0.677            2.6
# 584           0.677           11.0
# 585           0.677            1.4
# 586           0.677            3.6
# 587           0.677           11.0
# 588           0.677            1.9
# 589           0.677           14.3
# 590           0.006            1.6
# 591          51.499           11.8
# 592           0.003            1.2
# 593           0.006            2.9
# 594           0.023            9.0
# 595           0.003            1.2
# 596           0.026           11.6
# 597           0.006            2.8
# 598           0.032            2.7
# 599           0.016            1.4

# %% [markdown]
# # Check for missing values

# %%
data_df.isna().sum()
# Out:
# NDB_No             0
# Shrt_Desc          0
# Water_(g)          0
# Energ_Kcal         0
# Protein_(g)        0
# Lipid_Tot_(g)      1
# Ash_(g)            1
# Carbohydrt_(g)     0
# Fiber_TD_(g)       0
# Sugar_Tot_(g)      0
# Calcium_(mg)       0
# Iron_(mg)          0
# Magnesium_(mg)     0
# Phosphorus_(mg)    0
# Potassium_(mg)     0
# Sodium_(mg)        0
# Zinc_(mg)          0
# Copper_mg)         0
# Manganese_(mg)     0
# Selenium_(µg)      0
# dtype: int64

# %% [markdown]
# There are two missing values in the data set one for each variable lipid_Tot_(g) and Ash_(g). We need to drop these missing values before proceeding. We will use the dropna method to drop the missing values.

# %%
data_df = data_df.dropna()

# %%
data_df.isna().sum()
# Out:
# NDB_No             0
# Shrt_Desc          0
# Water_(g)          0
# Energ_Kcal         0
# Protein_(g)        0
# Lipid_Tot_(g)      0
# Ash_(g)            0
# Carbohydrt_(g)     0
# Fiber_TD_(g)       0
# Sugar_Tot_(g)      0
# Calcium_(mg)       0
# Iron_(mg)          0
# Magnesium_(mg)     0
# Phosphorus_(mg)    0
# Potassium_(mg)     0
# Sodium_(mg)        0
# Zinc_(mg)          0
# Copper_mg)         0
# Manganese_(mg)     0
# Selenium_(µg)      0
# dtype: int64

# %%
data_df.shape
# Out:
# (598, 20)

# %% [markdown]
# We can now see that there are no missing values in our data set.

# %% [markdown]
# # Summary of the data
#
# To see the summary of any dataframe we will use describe function.

# %%
data_df.describe()
# Out:
#             NDB_No   Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   598.000000  598.000000  598.000000   598.000000     598.000000
# mean   2305.448161   60.415870  186.521739     8.640385       8.849649
# std    1081.807819   31.929817  158.540534    10.939719      12.262311
# min    1001.000000    0.200000    0.000000     0.000000       0.000000
# 25%    1173.250000   39.167500   63.000000     1.702500       0.697500
# 50%    2052.500000   76.180000  106.000000     3.900000       3.475000
# 75%    3190.750000   85.987500  314.500000    12.385000      13.000000
# max    3953.000000   99.900000  876.000000    84.080000      99.480000
#
#           Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  598.000000      598.000000    598.000000     598.000000     598.00000
# mean     2.542040       19.395920      2.587458       9.122726     262.01505
# std      6.494483       21.522166      7.594803      13.927320     376.94743
# min      0.000000        0.000000      0.000000       0.000000       0.00000
# 25%      0.490000        5.560000      0.000000       0.560000      23.25000
# 50%      0.890000       10.840000      0.000000       4.820000     102.00000
# 75%      3.260000       19.147500      1.200000      10.692500     340.00000
# max     99.800000       86.680000     53.200000      74.460000    2240.00000
#
#         Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Potassium_(mg)  \
# count  598.000000      598.000000       598.000000      598.000000
# mean     4.371622       41.760870       188.610368      311.349498
# std     12.162654       81.460504       226.962501      496.549282
# min      0.000000        0.000000         0.000000        0.000000
# 25%      0.182500        8.000000        35.000000       95.000000
# 50%      0.415000       13.000000       100.500000      141.000000
# 75%      1.897500       33.000000       264.250000      255.000000
# max    123.600000      711.000000      1349.000000     4740.000000
#
#         Sodium_(mg)   Zinc_(mg)  Copper_mg)  Manganese_(mg)  Selenium_(µg)
# count    598.000000  598.000000  598.000000      598.000000     598.000000
# mean     348.270903    1.532475    0.151381        1.014246      12.426254
# std     1830.690933    1.970745    0.279639        4.220256      21.833695
# min        0.000000    0.000000    0.000000        0.000000       0.000000
# 25%       21.250000    0.300000    0.026000        0.021000       1.800000
# 50%       50.000000    0.670000    0.050000        0.140000       3.650000
# 75%      170.750000    2.360000    0.110000        0.677000      14.500000
# max    38758.000000   17.460000    2.467000       60.127000     208.100000

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 599
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NDB_No           598 non-null    int64
#  1   Shrt_Desc        598 non-null    object
#  2   Water_(g)        598 non-null    float64
#  3   Energ_Kcal       598 non-null    int64
#  4   Protein_(g)      598 non-null    float64
#  5   Lipid_Tot_(g)    598 non-null    float64
#  6   Ash_(g)          598 non-null    float64
#  7   Carbohydrt_(g)   598 non-null    float64
#  8   Fiber_TD_(g)     598 non-null    float64
#  9   Sugar_Tot_(g)    598 non-null    float64
#  10  Calcium_(mg)     598 non-null    int64
#  11  Iron_(mg)        598 non-null    float64
#  12  Magnesium_(mg)   598 non-null    int64
#  13  Phosphorus_(mg)  598 non-null    int64
#  14  Potassium_(mg)   598 non-null    int64
#  15  Sodium_(mg)      598 non-null    int64
#  16  Zinc_(mg)        598 non-null    float64
#  17  Copper_mg)       598 non-null    float64
#  18  Manganese_(mg)   598 non-null    float64
#  19  Selenium_(µg)    598 non-null    float64
# dtypes: float64(12), int64(7), object(1)
# memory usage: 98.1+ KB

# %% [markdown]
# # Create a vector “test” using the top 10 values of variable Protein_(g)
#
# we will pass the variable name inside the square brackets of data_df and then use head function to retrieve the top 10 records.

# %%
test = data_df['Protein_(g)'].head(10)

# %%
test
# Out:
# 0      0.85
# 1      0.49
# 2      0.28
# 5     20.75
# 6     19.80
# 7     25.18
# 8     22.87
# 9     23.37
# 10    23.76
# 11    11.12
# Name: Protein_(g), dtype: float64

# %%
data_df
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 5      1006                                        CHEESE,BRIE      48.42
# 6      1007                                   CHEESE,CAMEMBERT      51.80
# ..      ...                                                ...        ...
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0           717         0.85          81.11     2.11            0.06
# 1           718         0.49          78.30     1.62            2.87
# 2           876         0.28          99.48     0.00            0.00
# 5           334        20.75          27.68     2.70            0.45
# 6           300        19.80          24.26     3.68            0.46
# ..          ...          ...            ...      ...             ...
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# 0             0.0           0.06            24       0.02               2
# 1             0.0           0.06            23       0.05               1
# 2             0.0           0.00             4       0.00               0
# 5             0.0           0.45           184       0.50              20
# 6             0.0           0.46           388       0.33              20
# ..            ...            ...           ...        ...             ...
# 595           0.0           6.90            53       1.18               4
# 596           0.0          54.73           410       9.47              32
# 597           0.0          13.52            99       2.30               8
# 598           0.0          13.10           134       2.30              10
# 599           0.0           6.70            69       1.18               5
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 0                 24              24          643       0.09       0.000
# 1                 24              41          583       0.05       0.010
# 2                  3               5            2       0.01       0.001
# 5                188             152          629       2.38       0.019
# 6                347             187          842       2.38       0.021
# ..               ...             ...          ...        ...         ...
# 595               28              69           16       0.49       0.059
# 596              221             552          126       3.94       0.473
# 597               54             134           31       0.96       0.115
# 598               96             138           56       0.96       0.096
# 599               49              71           29       0.49       0.049
#
#      Manganese_(mg)  Selenium_(µg)
# 0             0.000            1.0
# 1             0.001            0.0
# 2             0.000            0.0
# 5             0.034           14.5
# 6             0.038           14.5
# ..              ...            ...
# 595           0.003            1.2
# 596           0.026           11.6
# 597           0.006            2.8
# 598           0.032            2.7
# 599           0.016            1.4
#
# [598 rows x 20 columns]

# %% [markdown]
# # Select the top 5 rows of initial 5 variables in a matrix format

# %% [markdown]
# To fetch the top 5 rows and initial variables we will use iloc and will pass the index both for rows and columns.

# %%
data_df.iloc[0:5, 0:5]
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80

# %% [markdown]
# # What is the class of the Sodium_(mg) variable

# %%
data_df['Sodium_(mg)'].dtype
# Out:
# dtype('int64')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 599
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NDB_No           598 non-null    int64
#  1   Shrt_Desc        598 non-null    object
#  2   Water_(g)        598 non-null    float64
#  3   Energ_Kcal       598 non-null    int64
#  4   Protein_(g)      598 non-null    float64
#  5   Lipid_Tot_(g)    598 non-null    float64
#  6   Ash_(g)          598 non-null    float64
#  7   Carbohydrt_(g)   598 non-null    float64
#  8   Fiber_TD_(g)     598 non-null    float64
#  9   Sugar_Tot_(g)    598 non-null    float64
#  10  Calcium_(mg)     598 non-null    int64
#  11  Iron_(mg)        598 non-null    float64
#  12  Magnesium_(mg)   598 non-null    int64
#  13  Phosphorus_(mg)  598 non-null    int64
#  14  Potassium_(mg)   598 non-null    int64
#  15  Sodium_(mg)      598 non-null    int64
#  16  Zinc_(mg)        598 non-null    float64
#  17  Copper_mg)       598 non-null    float64
#  18  Manganese_(mg)   598 non-null    float64
#  19  Selenium_(µg)    598 non-null    float64
# dtypes: float64(12), int64(7), object(1)
# memory usage: 98.1+ KB

# %% [markdown]
# # Create a new variable “EPW” by dividing Energ_Kcal with the Water; what is the dimension of the new dataset?

# %%
data_df.shape
# Out:
# (598, 20)

# %%
data_df['EPW'] = data_df['Energ_Kcal']/ data_df['Water_(g)']
# Out:
# C:\Users\Shohel Noor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_df.shape
# Out:
# (598, 21)

# %%
data_df
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 5      1006                                        CHEESE,BRIE      48.42
# 6      1007                                   CHEESE,CAMEMBERT      51.80
# ..      ...                                                ...        ...
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0           717         0.85          81.11     2.11            0.06
# 1           718         0.49          78.30     1.62            2.87
# 2           876         0.28          99.48     0.00            0.00
# 5           334        20.75          27.68     2.70            0.45
# 6           300        19.80          24.26     3.68            0.46
# ..          ...          ...            ...      ...             ...
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  ...  Iron_(mg)  Magnesium_(mg)  \
# 0             0.0           0.06  ...       0.02               2
# 1             0.0           0.06  ...       0.05               1
# 2             0.0           0.00  ...       0.00               0
# 5             0.0           0.45  ...       0.50              20
# 6             0.0           0.46  ...       0.33              20
# ..            ...            ...  ...        ...             ...
# 595           0.0           6.90  ...       1.18               4
# 596           0.0          54.73  ...       9.47              32
# 597           0.0          13.52  ...       2.30               8
# 598           0.0          13.10  ...       2.30              10
# 599           0.0           6.70  ...       1.18               5
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 0                 24              24          643       0.09       0.000
# 1                 24              41          583       0.05       0.010
# 2                  3               5            2       0.01       0.001
# 5                188             152          629       2.38       0.019
# 6                347             187          842       2.38       0.021
# ..               ...             ...          ...        ...         ...
# 595               28              69           16       0.49       0.059
# 596              221             552          126       3.94       0.473
# 597               54             134           31       0.96       0.115
# 598               96             138           56       0.96       0.096
# 599               49              71           29       0.49       0.049
#
#      Manganese_(mg)  Selenium_(µg)          EPW
# 0             0.000            1.0    45.179584
# 1             0.001            0.0    42.942584
# 2             0.000            0.0  3650.000000
# 5             0.034           14.5     6.897976
# 6             0.038           14.5     5.791506
# ..              ...            ...          ...
# 595           0.003            1.2     0.751794
# 596           0.026           11.6   232.000000
# 597           0.006            2.8     1.667542
# 598           0.032            2.7     1.688432
# 599           0.016            1.4     0.753941
#
# [598 rows x 21 columns]

# %% [markdown]
# # Create a subset of the dataset, where the Energ_Kcal is less than 500, what is the dimension of this new dataset?

# %% [markdown]
# We will create a new data frame by using the subset conditions from the original data_df and will use shape property for checking the dimension.

# %%
data_df.shape
# Out:
# (598, 21)

# %%
data_df_new = data_df[data_df['Energ_Kcal'] < 500]

# %%
data_df_new.shape
# Out:
# (562, 21)

# %% [markdown]
# # Find the top 10 products based on following
#
# 1. Higher the Energy_Kcal, higher the ranking

# %% [markdown]
# Here we will use sorting to find out based on higher energy values.We will use sort_values method to order the data. Since we are saying higher trhe value the rank needs to be higher we will sort the data in the descending order so that the top most value gets the higher rank.

# %%
data_df.sort_values(by = 'Energ_Kcal', ascending = False).head(10)
# Out:
#      NDB_No                             Shrt_Desc  Water_(g)  Energ_Kcal  \
# 2      1003                  BUTTER OIL,ANHYDROUS       0.24         876
# 1      1002                BUTTER,WHIPPED,W/ SALT      16.72         718
# 0      1001                      BUTTER,WITH SALT      15.87         717
# 131    1145                   BUTTER,WITHOUT SALT      17.94         717
# 125    1137                        EGG,YOLK,DRIED       3.08         669
# 122    1134  EGG,WHL,DRIED,STABILIZED,GLUCOSE RED       1.87         615
# 121    1133                         EGG,WHL,DRIED       2.78         592
# 63     1070              DESSERT TOPPING,POWDERED       1.47         577
# 178    1210                    EGG MIX,USDA CMDTY       2.78         555
# 62     1069             CREAM SUBSTITUTE,POWDERED       2.98         529
#
#      Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 2           0.28          99.48     0.00            0.00           0.0
# 1           0.49          78.30     1.62            2.87           0.0
# 0           0.85          81.11     2.11            0.06           0.0
# 131         0.85          81.11     0.09            0.06           0.0
# 125        33.63          59.13     3.51            0.66           0.0
# 122        48.17          43.95     3.63            2.38           0.0
# 121        48.05          43.90     4.13            1.13           0.0
# 63          4.90          39.92     1.17           52.54           0.0
# 178        35.60          34.50     3.15           23.97           0.0
# 62          2.48          32.92     2.34           59.29           0.0
#
#      Sugar_Tot_(g)  ...  Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  \
# 2             0.00  ...       0.00               0                3
# 1             0.06  ...       0.05               1               24
# 0             0.06  ...       0.02               2               24
# 131           0.06  ...       0.02               2               24
# 125           0.23  ...       9.56              26             1040
# 122           0.00  ...       8.28              49              715
# 121           0.56  ...       7.20              34              629
# 63           52.54  ...       0.03               7               74
# 178           2.46  ...       3.23              11              451
# 62            7.77  ...       0.26               1              288
#
#      Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  Manganese_(mg)  \
# 2                 5            2       0.01       0.001           0.000
# 1                41          583       0.05       0.010           0.001
# 0                24          643       0.09       0.000           0.000
# 131              24           11       0.09       0.016           0.004
# 125             264          149       7.73       0.000           0.185
# 122             515          548       5.71       0.270           0.150
# 121             540          476       3.15       0.203           0.058
# 63              166          122       0.08       0.118           0.225
# 178             373          576       2.76       0.149           0.056
# 62              669          124       0.07       0.018           0.011
#
#      Selenium_(µg)          EPW
# 2              0.0  3650.000000
# 1              0.0    42.942584
# 0              1.0    45.179584
# 131            1.0    39.966555
# 125          139.3   217.207792
# 122          121.1   328.877005
# 121          164.7   212.949640
# 63             0.6   392.517007
# 178          118.0   199.640288
# 62             0.0   177.516779
#
# [10 rows x 21 columns]

# %%
data_df.sort_values(by = 'Energ_Kcal', ascending = True).tail(10)
# Out:
#      NDB_No                             Shrt_Desc  Water_(g)  Energ_Kcal  \
# 62     1069             CREAM SUBSTITUTE,POWDERED       2.98         529
# 178    1210                    EGG MIX,USDA CMDTY       2.78         555
# 63     1070              DESSERT TOPPING,POWDERED       1.47         577
# 121    1133                         EGG,WHL,DRIED       2.78         592
# 122    1134  EGG,WHL,DRIED,STABILIZED,GLUCOSE RED       1.87         615
# 125    1137                        EGG,YOLK,DRIED       3.08         669
# 131    1145                   BUTTER,WITHOUT SALT      17.94         717
# 0      1001                      BUTTER,WITH SALT      15.87         717
# 1      1002                BUTTER,WHIPPED,W/ SALT      16.72         718
# 2      1003                  BUTTER OIL,ANHYDROUS       0.24         876
#
#      Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 62          2.48          32.92     2.34           59.29           0.0
# 178        35.60          34.50     3.15           23.97           0.0
# 63          4.90          39.92     1.17           52.54           0.0
# 121        48.05          43.90     4.13            1.13           0.0
# 122        48.17          43.95     3.63            2.38           0.0
# 125        33.63          59.13     3.51            0.66           0.0
# 131         0.85          81.11     0.09            0.06           0.0
# 0           0.85          81.11     2.11            0.06           0.0
# 1           0.49          78.30     1.62            2.87           0.0
# 2           0.28          99.48     0.00            0.00           0.0
#
#      Sugar_Tot_(g)  ...  Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  \
# 62            7.77  ...       0.26               1              288
# 178           2.46  ...       3.23              11              451
# 63           52.54  ...       0.03               7               74
# 121           0.56  ...       7.20              34              629
# 122           0.00  ...       8.28              49              715
# 125           0.23  ...       9.56              26             1040
# 131           0.06  ...       0.02               2               24
# 0             0.06  ...       0.02               2               24
# 1             0.06  ...       0.05               1               24
# 2             0.00  ...       0.00               0                3
#
#      Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  Manganese_(mg)  \
# 62              669          124       0.07       0.018           0.011
# 178             373          576       2.76       0.149           0.056
# 63              166          122       0.08       0.118           0.225
# 121             540          476       3.15       0.203           0.058
# 122             515          548       5.71       0.270           0.150
# 125             264          149       7.73       0.000           0.185
# 131              24           11       0.09       0.016           0.004
# 0                24          643       0.09       0.000           0.000
# 1                41          583       0.05       0.010           0.001
# 2                 5            2       0.01       0.001           0.000
#
#      Selenium_(µg)          EPW
# 62             0.0   177.516779
# 178          118.0   199.640288
# 63             0.6   392.517007
# 121          164.7   212.949640
# 122          121.1   328.877005
# 125          139.3   217.207792
# 131            1.0    39.966555
# 0              1.0    45.179584
# 1              0.0    42.942584
# 2              0.0  3650.000000
#
# [10 rows x 21 columns]

# %% [markdown]
# 2. Lower the water content, higher the ranking
#
# Since we are saying lower trhe value the rank needs to be higher we will sort the data in the ascending order so that the lower most value gets the higher rank.

# %%
data_df.sort_values(by= ['Water_(g)', 'Energ_Kcal'], ascending = True).head(10)
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 295    2047                                         SALT,TABLE       0.20
# 311    2074        SEASONING MIX,DRY,SAZON,CORIANDER & ANNATTO       0.20
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 63     1070                           DESSERT TOPPING,POWDERED       1.47
# 175    1206                                 CREAM SUB,FLAV,PDR       1.52
# 443    3184           BABYFOOD,CRL,WHL WHEAT,W/ APPLS,DRY FORT       1.70
# 122    1134               EGG,WHL,DRIED,STABILIZED,GLUCOSE RED       1.87
# 461    3209                              BABYFOOD,CRACKERS,VEG       2.00
# 587    3941       INF FORMULA,PBM PRODUCTS,STORE BRAND,SOY,PDR       2.00
# 535    3821  INF FORMULA. MEAD JOHNSON, PREGESTIMIL, W/IRON...       2.00
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 295           0         0.00           0.00    99.80            0.00
# 311           0         0.00           0.00    99.80            0.00
# 2           876         0.28          99.48     0.00            0.00
# 63          577         4.90          39.92     1.17           52.54
# 175         482         0.68          21.47     0.79           75.42
# 443         402         6.60           4.80     3.70           83.20
# 122         615        48.17          43.95     3.63            2.38
# 461         477         8.40          19.60     3.15           66.85
# 587         508        13.60          27.20     5.00           52.20
# 535         519        14.00          28.00     3.20           52.80
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  ...  Iron_(mg)  Magnesium_(mg)  \
# 295           0.0           0.00  ...       0.33               1
# 311           0.0           0.00  ...       0.00             100
# 2             0.0           0.00  ...       0.00               0
# 63            0.0          52.54  ...       0.03               7
# 175           1.2          58.01  ...       0.63              17
# 443           6.7          26.66  ...      45.00             140
# 122           0.0           0.00  ...       8.28              49
# 461           4.0          13.00  ...       4.20              37
# 587           0.0          52.20  ...       9.10              51
# 535           0.0          51.00  ...       9.40              55
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# 295                0               8        38758       0.10       0.030
# 311              150              89        17000       0.88       0.008
# 2                  3               5            2       0.01       0.001
# 63                74             166          122       0.08       0.118
# 175               28              90          123       0.23       0.135
# 443              200             500           66       2.60       0.620
# 122              715             515          548       5.71       0.270
# 461              198             245          571       0.90       0.130
# 587              317             528          151       3.80       0.355
# 535              380             550          240       5.00       0.380
#
#      Manganese_(mg)  Selenium_(µg)          EPW
# 295           0.100            0.1     0.000000
# 311           0.677           43.4     0.000000
# 2             0.000            0.0  3650.000000
# 63            0.225            0.6   392.517007
# 175           0.140            1.3   317.105263
# 443           2.520           64.7   236.470588
# 122           0.150          121.1   328.877005
# 461           0.770           13.7   238.500000
# 587           0.677           11.0   254.000000
# 535           0.677           14.0   259.500000
#
# [10 rows x 21 columns]

# %%
data_df['Water_(g)'].value_counts()  #value_count(['Water_(g)'])
# Out:
# 2.50     7
# 88.35    6
# 87.50    6
# 2.25     5
# 3.00     5
#         ..
# 80.14    1
# 44.29    1
# 77.50    1
# 7.79     1
# 92.30    1
# Name: Water_(g), Length: 436, dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 599
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NDB_No           598 non-null    int64
#  1   Shrt_Desc        598 non-null    object
#  2   Water_(g)        598 non-null    float64
#  3   Energ_Kcal       598 non-null    int64
#  4   Protein_(g)      598 non-null    float64
#  5   Lipid_Tot_(g)    598 non-null    float64
#  6   Ash_(g)          598 non-null    float64
#  7   Carbohydrt_(g)   598 non-null    float64
#  8   Fiber_TD_(g)     598 non-null    float64
#  9   Sugar_Tot_(g)    598 non-null    float64
#  10  Calcium_(mg)     598 non-null    int64
#  11  Iron_(mg)        598 non-null    float64
#  12  Magnesium_(mg)   598 non-null    int64
#  13  Phosphorus_(mg)  598 non-null    int64
#  14  Potassium_(mg)   598 non-null    int64
#  15  Sodium_(mg)      598 non-null    int64
#  16  Zinc_(mg)        598 non-null    float64
#  17  Copper_mg)       598 non-null    float64
#  18  Manganese_(mg)   598 non-null    float64
#  19  Selenium_(µg)    598 non-null    float64
#  20  EPW              598 non-null    float64
# dtypes: float64(13), int64(7), object(1)
# memory usage: 102.8+ KB

# %% [markdown]
# # Create a subset of the data where product_desc contains “CHEESE” and list down the summary statistics of the subset

# %%
data_df_cheese = data_df[data_df['Shrt_Desc'].str.contains("CHEESE")]

# %% [markdown]
# To find a specific value we will use the contains method. We will pass the string in the paranthesis which needs to be located in the dataframe variable.

# %%
data_df_cheese.shape
# Out:
# (74, 21)

# %% [markdown]
# # Using the cut function on water variable divide the whole data into 6 bins, list down the summary statistics of all the 6 bins.

# %%
data_bins = data_df

# %%
data_bins['bins.water'] = pd.cut(data_bins['Water_(g)'], 5)
# Out:
# C:\Users\Shohel Noor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_bins['bins.water'].unique()
# Out:
# [(0.1, 20.14], (40.08, 60.02], (20.14, 40.08], (60.02, 79.96], (79.96, 99.9]]
# Categories (5, interval[float64]): [(0.1, 20.14] < (20.14, 40.08] < (40.08, 60.02] < (60.02, 79.96] < (79.96, 99.9]]

# %%
import seaborn as sns
sns.distplot(data_bins['Water_(g)'], bins = 5)
# Out:
# <AxesSubplot:xlabel='Water_(g)'>

# %%
data_bins
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 5      1006                                        CHEESE,BRIE      48.42
# 6      1007                                   CHEESE,CAMEMBERT      51.80
# ..      ...                                                ...        ...
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0           717         0.85          81.11     2.11            0.06
# 1           718         0.49          78.30     1.62            2.87
# 2           876         0.28          99.48     0.00            0.00
# 5           334        20.75          27.68     2.70            0.45
# 6           300        19.80          24.26     3.68            0.46
# ..          ...          ...            ...      ...             ...
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  ...  Magnesium_(mg)  Phosphorus_(mg)  \
# 0             0.0           0.06  ...               2               24
# 1             0.0           0.06  ...               1               24
# 2             0.0           0.00  ...               0                3
# 5             0.0           0.45  ...              20              188
# 6             0.0           0.46  ...              20              347
# ..            ...            ...  ...             ...              ...
# 595           0.0           6.90  ...               4               28
# 596           0.0          54.73  ...              32              221
# 597           0.0          13.52  ...               8               54
# 598           0.0          13.10  ...              10               96
# 599           0.0           6.70  ...               5               49
#
#      Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  Manganese_(mg)  \
# 0                24          643       0.09       0.000           0.000
# 1                41          583       0.05       0.010           0.001
# 2                 5            2       0.01       0.001           0.000
# 5               152          629       2.38       0.019           0.034
# 6               187          842       2.38       0.021           0.038
# ..              ...          ...        ...         ...             ...
# 595              69           16       0.49       0.059           0.003
# 596             552          126       3.94       0.473           0.026
# 597             134           31       0.96       0.115           0.006
# 598             138           56       0.96       0.096           0.032
# 599              71           29       0.49       0.049           0.016
#
#      Selenium_(µg)          EPW      bins.water
# 0              1.0    45.179584  (10.17, 20.14]
# 1              0.0    42.942584  (10.17, 20.14]
# 2              0.0  3650.000000    (0.1, 10.17]
# 5             14.5     6.897976  (40.08, 50.05]
# 6             14.5     5.791506  (50.05, 60.02]
# ..             ...          ...             ...
# 595            1.2     0.751794  (79.96, 89.93]
# 596           11.6   232.000000    (0.1, 10.17]
# 597            2.8     1.667542  (69.99, 79.96]
# 598            2.7     1.688432  (69.99, 79.96]
# 599            1.4     0.753941  (79.96, 89.93]
#
# [598 rows x 22 columns]

# %%
data_bins['bins.water'].unique()
# Out:
# [(10.17, 20.14], (0.1, 10.17], (40.08, 50.05], (50.05, 60.02], (30.11, 40.08], (69.99, 79.96], (79.96, 89.93], (60.02, 69.99], (20.14, 30.11], (89.93, 99.9]]
# Categories (10, interval[float64]): [(0.1, 10.17] < (10.17, 20.14] < (20.14, 30.11] < (30.11, 40.08] ... (60.02, 69.99] < (69.99, 79.96] < (79.96, 89.93] < (89.93, 99.9]]

# %%
data_bins['bins'] = pd.cut(data_bins['Water_(g)'], 6, labels = [ "a", "b", "c", "d", "e", "f"])
# Out:
# C:\Users\Shohel Noor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_bins
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 5      1006                                        CHEESE,BRIE      48.42
# 6      1007                                   CHEESE,CAMEMBERT      51.80
# ..      ...                                                ...        ...
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0           717         0.85          81.11     2.11            0.06
# 1           718         0.49          78.30     1.62            2.87
# 2           876         0.28          99.48     0.00            0.00
# 5           334        20.75          27.68     2.70            0.45
# 6           300        19.80          24.26     3.68            0.46
# ..          ...          ...            ...      ...             ...
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  ...  Phosphorus_(mg)  Potassium_(mg)  \
# 0             0.0           0.06  ...               24              24
# 1             0.0           0.06  ...               24              41
# 2             0.0           0.00  ...                3               5
# 5             0.0           0.45  ...              188             152
# 6             0.0           0.46  ...              347             187
# ..            ...            ...  ...              ...             ...
# 595           0.0           6.90  ...               28              69
# 596           0.0          54.73  ...              221             552
# 597           0.0          13.52  ...               54             134
# 598           0.0          13.10  ...               96             138
# 599           0.0           6.70  ...               49              71
#
#      Sodium_(mg)  Zinc_(mg)  Copper_mg)  Manganese_(mg)  Selenium_(µg)  \
# 0            643       0.09       0.000           0.000            1.0
# 1            583       0.05       0.010           0.001            0.0
# 2              2       0.01       0.001           0.000            0.0
# 5            629       2.38       0.019           0.034           14.5
# 6            842       2.38       0.021           0.038           14.5
# ..           ...        ...         ...             ...            ...
# 595           16       0.49       0.059           0.003            1.2
# 596          126       3.94       0.473           0.026           11.6
# 597           31       0.96       0.115           0.006            2.8
# 598           56       0.96       0.096           0.032            2.7
# 599           29       0.49       0.049           0.016            1.4
#
#              EPW      bins.water  bins
# 0      45.179584  (10.17, 20.14]     a
# 1      42.942584  (10.17, 20.14]     a
# 2    3650.000000    (0.1, 10.17]     a
# 5       6.897976  (40.08, 50.05]     c
# 6       5.791506  (50.05, 60.02]     d
# ..           ...             ...   ...
# 595     0.751794  (79.96, 89.93]     f
# 596   232.000000    (0.1, 10.17]     a
# 597     1.667542  (69.99, 79.96]     e
# 598     1.688432  (69.99, 79.96]     e
# 599     0.753941  (79.96, 89.93]     f
#
# [598 rows x 23 columns]
