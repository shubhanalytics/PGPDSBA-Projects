# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
all_sheets = pd.read_excel(r'D:\Tableau\Netflix.xlsx', sheet_name = None)
all_sheets
# Out:
# {'netflix_titles':      duration_minutes duration_seasons     type  \
#  0                  90              NaN    Movie
#  1                  94              NaN    Movie
#  2                 NaN                1  TV Show
#  3                 NaN                1  TV Show
#  4                  99              NaN    Movie
#  ...               ...              ...      ...
#  6231              NaN               13  TV Show
#  6232              NaN                4  TV Show
#  6233               60              NaN    Movie
#  6234              NaN                2  TV Show
#  6235              NaN               10  TV Show
#
#                                              title           date_added  \
#  0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
#  1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
#  2                              Transformers Prime  2018-09-08 00:00:00
# ...

# %%
df_netflix_titles = all_sheets['netflix_titles']
df_netflix_titles_directors = all_sheets['netflix_titles_directors']
df_netflix_titles_countries = all_sheets['netflix_titles_countries']
df_netflix_titles_cast = all_sheets['netflix_titles_cast']
df_netflix_titles_category = all_sheets['netflix_titles_category']

# %%
print('df_nextflix_titles:',df_netflix_titles.shape)
print('df_nextflix_titles_directors:',df_netflix_titles_directors.shape)
print('df_nextflix_titles_countries:',df_netflix_titles_countries.shape)
print('df_nextflix_titles_cast:',df_netflix_titles_cast.shape)
print('df_nextflix_titles_category:',df_netflix_titles_category.shape)
# Out:
# df_nextflix_titles: (6236, 9)
# df_nextflix_titles_directors: (4852, 2)
# df_nextflix_titles_countries: (7179, 2)
# df_nextflix_titles_cast: (44311, 2)
# df_nextflix_titles_category: (13670, 2)
