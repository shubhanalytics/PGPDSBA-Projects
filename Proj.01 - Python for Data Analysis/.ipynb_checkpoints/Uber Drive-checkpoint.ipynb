# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhanalytics/PGPDSBA-Projects/blob/main/Proj.01%20-%20Python%20for%20Data%20Analysis/Uber%20Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UBER DRIVE ANALYSIS : The project is based on the trips made by Uber drivers. Different aspects of the trip are analyzed by using different functions in Python.

# %% [markdown]
# Load the necessary libraries. Import and load the dataset with a name uber.

# %%
import numpy as np, pandas as pd, seaborn as sns, os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(os.getcwd()) # checking the current working directory and printing in the output to get confirmed
# Out:
# D:\My Data\Professional\Analytics\PGPDSBA-Projects\Proj.01 - Python for Data Analysis

# %%
# load the csv file uberdrive.csv
uber = pd.read_csv(r'D:\My Data\Professional\Analytics\PGPDSBA-Projects\Proj.01 - Python for Data Analysis\Uber_Drive.csv') 

uber.head() #read the file and check the first 5 rows
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber.tail(10)   # Displaying the last 10 records of the dataset
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# ...

# %%
uber.shape  # showing the shape or dimension(number of rows, number of columns) of the dataset
# Out:
# (1155, 7)

# %%
uber.size   # showing the size(rows * columns) of the dataset
# Out:
# 8085

# %%
uber.info()    # displaying the information about all the variables of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# In the above dataset info, below are the few observations:
#
# 1. There are 1155 non-null values in first 6 columns, but there are only 653 non-null values in the 'purpose' column, which means 502 values are null in 'purpose' column. We need to review and correct it.
#
# 2. Only the 'Miles' column is in float datatype, rest all columns are in object datatype, which requires our manual review and correction.

# %%
uber.isnull().any()    # checking the missing values in the dataset in the boolean(True or False) format
# Out:
# START_DATE*    False
# END_DATE*      False
# CATEGORY*      False
# START*         False
# STOP*          False
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
uber.isnull().sum()  # checking the missing values in the dataset in the integer format
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
uber.isnull().sum().sum()   # displaying the total number of missing values across all the variables
# Out:
# np.int64(502)

# %%
uber.describe()   # Summary of the original data including : Count,Mean, Std, Min, 25%,50%,75% and max
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# In the above summary, we can see that the maximum miles driven by an uber drive is 310, and the minimum miles is 0.50

# %%
df = uber.copy()  # copied the original dataset(uber) to df

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df = df.dropna() # dropped the missing values from the df

df.head()  #display 'df' which does not contain any missing values
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain

# %%
print(f"shape of dataset after dropped missing values: {df.shape}")
print(f"size of dataset after dropped missing values: {df.size}")
# Out:
# shape of dataset after dropped missing values: (653, 7)
# size of dataset after dropped missing values: 4571

# %%
df.info()   #dataframe 'df' information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %%
new_column_names = {'START_DATE*':'start_date',\
                     'END_DATE*':'end_date',\
                     'CATEGORY*':'category',\
                     'START*':'start',\
                     'STOP*':'stop',\
                     'MILES*':'miles',\
                     'PURPOSE*':'purpose'}

# %%
df = df.rename(columns = new_column_names)

# %%
df.columns
# Out:
# Index(['start_date', 'end_date', 'category', 'start', 'stop', 'miles',
#        'purpose'],
#       dtype='object')

# %%
df.head()
# Out:
#        start_date        end_date  category            start             stop  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
#
#    miles          purpose
# 0    5.1   Meal/Entertain
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit
# 5    4.3   Meal/Entertain

# %%
print(df['start'].nunique())   # getting the unique START places names
# Out:
# 131

# %%
df['start'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %%
df['start'].value_counts().head(20)
# Out:
# start
# Cary                161
# Unknown Location     55
# Morrisville          54
# Whitebridge          36
# Durham               30
# Karachi              26
# Raleigh              21
# Lahore               19
# Islamabad            15
# Midtown              11
# Apex                 11
# Berkeley              8
# San Francisco         7
# The Drag              6
# Westpark Place        5
# Kissimmee             5
# Rawalpindi            5
# Orlando               4
# Fort Pierce           4
# Hazelwood             4
# Name: count, dtype: int64

# %%
# displaying total number of unique START destinations of original dataframe 'uber'

uber['START*'].nunique()
# Out:
# 176

# %%
# displaying total number of unique STOP destinations of original dataframe 'uber'

uber['STOP*'].nunique()
# Out:
# 187

# %%
#Let's check the rides with the starting point as 'san fransisco'

# Now, selecting the index column as 'START*'

df_sf = pd.read_csv(r'D:\My Data\Professional\Analytics\PGPDSBA-Projects\Proj.01 - Python for Data Analysis\Uber_Drive.csv', index_col='START*')

# selecting the rows which has starting point of San Francisco using loc function and assign it to new variable
uber_trips_SF = df_sf.loc['San Francisco']


# displaying all the uber trips that has starting point of San Francisco
uber_trips_SF
# Out:
#                     START_DATE*         END_DATE* CATEGORY*       STOP*  \
# START*
# San Francisco    5/9/2016 14:39    5/9/2016 15:06  Business   Palo Alto
# San Francisco   6/14/2016 16:09   6/14/2016 16:39  Business  Emeryville
# San Francisco  10/19/2016 14:02  10/19/2016 14:31  Business    Berkeley
# San Francisco   11/7/2016 19:17   11/7/2016 19:57  Business    Berkeley
# San Francisco   11/8/2016 12:16   11/8/2016 12:49  Business    Berkeley
# San Francisco   11/9/2016 18:40   11/9/2016 19:17  Business     Oakland
# San Francisco  11/10/2016 15:17  11/10/2016 15:22  Business     Oakland
# San Francisco  11/15/2016 20:44  11/15/2016 21:00  Business    Berkeley
#
#                MILES*         PURPOSE*
# START*
# San Francisco    20.5  Between Offices
# San Francisco    11.6          Meeting
# San Francisco    10.8              NaN
# San Francisco    13.2  Between Offices
# San Francisco    11.3          Meeting
# San Francisco    12.7   Customer Visit
# ...

# %%
uber_trips_SF.shape
# Out:
# (8, 6)

# %%
uber_trips_SF.value_counts()   # summing up all the numerical columns of the dataframe 'uber_trips_SF'
# Out:
# START_DATE*       END_DATE*         CATEGORY*  STOP*       MILES*  PURPOSE*
# 11/10/2016 15:17  11/10/2016 15:22  Business   Oakland     9.9     Temporary Site     1
# 11/15/2016 20:44  11/15/2016 21:00  Business   Berkeley    11.8    Temporary Site     1
# 11/7/2016 19:17   11/7/2016 19:57   Business   Berkeley    13.2    Between Offices    1
# 11/8/2016 12:16   11/8/2016 12:49   Business   Berkeley    11.3    Meeting            1
# 11/9/2016 18:40   11/9/2016 19:17   Business   Oakland     12.7    Customer Visit     1
# 5/9/2016 14:39    5/9/2016 15:06    Business   Palo Alto   20.5    Between Offices    1
# 6/14/2016 16:09   6/14/2016 16:39   Business   Emeryville  11.6    Meeting            1
# Name: count, dtype: int64

# %%
# Most popular starting point in the original dataset 'uber'

print('The most popular starting point for the uber trips is:', uber['START*'].value_counts().idxmax())
print('_____________________')
print('See the below data to verify:\n\n', uber['START*'].value_counts().sort_values(ascending=False).head(5))
# Out:
# The most popular starting point for the uber trips is: Cary
# _____________________
# See the below data to verify:
#
#  START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: count, dtype: int64

# %%
# most popular dropping point from the original dataset 'uber'

print('The most popular dropping point for the Uber trips is:', uber['STOP*'].value_counts().idxmax())
print('_________________________')
print('See the below data to verify:\n\n', uber['STOP*'].value_counts().sort_values(ascending=False).head(5))
# Out:
# The most popular dropping point for the Uber trips is: Cary
# _________________________
# See the below data to verify:
#
#  STOP*
# Cary                203
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
# Name: count, dtype: int64

# %%
# most frequent route taken by uber drivers (using original dataset 'uber')

most_frequent = (uber.groupby(['START*', 'STOP*']).size().reset_index(name='count_of_trips').sort_values('count_of_trips', ascending=False).head())

most_frequent
# Out:
#                START*             STOP*  count_of_trips
# 318  Unknown Location  Unknown Location              86
# 203       Morrisville              Cary              75
# 46               Cary       Morrisville              67
# 40               Cary              Cary              53
# 42               Cary            Durham              36

# %%
# pip install pandasql

# %%
df.query("miles > 50")
# Out:
#             start_date          end_date  category          start  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business    Fort Pierce
# 232    3/17/2016 12:52   3/17/2016 15:11  Business         Austin
# 251    3/19/2016 19:33   3/19/2016 20:39  Business      Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business           Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business          Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business   Jacksonville
# 295     4/2/2016 12:21    4/2/2016 14:47  Business      Kissimmee
# 296     4/2/2016 16:57    4/2/2016 18:09  Business  Daytona Beach
# 297     4/2/2016 19:38    4/2/2016 22:36  Business   Jacksonville
# 298     4/2/2016 23:11     4/3/2016 1:34  Business      Ridgeland
# 299      4/3/2016 2:00     4/3/2016 4:16  Business       Florence
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal          Boone
# 869   10/28/2016 15:53  10/28/2016 17:59  Business           Cary
# ...

# %%
#displaying all types of purposes for the trip in an array from the dataframe 'df' with no 'NA' values

df['purpose'].unique()
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %%
uber['PURPOSE*'].unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint:You have to plot total/sum miles per purpose

# %%
uber_drives.groupby(['PURPOSE*']).sum()

new_dataset = {'Airport/Travel':16.5, 'Between Offices':197.0, 'Charity($)':15.1, 'Commute':180.2, 'Customer Visit':2089.5,
              'Errand/Supplies':508.0, 'Meal/Entertain':911.7, 'Meeting':2851.3, 'Moving':18.2, 'Temporary Site':523.7}


purpose = list(new_dataset.keys())
miles = list(new_dataset.values())

fig = plt.figure(figsize = (17, 10))

plt.bar(purpose, miles, color ='green', width = 0.4)
plt.title("Total/Sum miles per purpose")
plt.xlabel("purpose")
plt.ylabel("miles")

plt.show()

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the distance travelled for that particular Purpose. (3 points)
# #### Note: Use the original dataframe without dropping "NA" values

# %%
# Displaying a dataframe of Purpose and the distance travelled for that particular Purpose

uber_drives.groupby(['PURPOSE*']).sum()

# %% [markdown]
# ## Q21. Plot number of trips vs Category of trips. (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint : You can make a countplot or barplot.

# %%
uber_drives.groupby(['CATEGORY*']).groups

# %% [markdown]
# ## Q22. What is proportion of miles that are covered as Business trips and what is the proportion of miles that are covered as Personal trips? (3 points)
#
# ### Note:Use the original dataframe without dropping the 'NA' values. The proportion calculation  is with respect to the 'miles' variable.
#
# #### Hint: Proportion of miles covered as business trips= (Total Miles clocked as Business Trips)/ (Total Miles)
# #### Proportion of miles covered as personal trips= (Total Miles clocked as Personal Trips)/ (Total Miles)

# %%
total_miles = uber_drives['MILES*'].sum()    # sum of miles = 12204.7
print('Total Miles = ',total_miles)

print('______________________')

miles_per_category = uber_drives.groupby(['CATEGORY*']).sum()

print('\nMiles per category are shown as below = \n\n', miles_per_category)

print('______________________')

#Proportion of miles covered as business trips= (Total Miles clocked as Business Trips)/ (Total Miles)

Proportion_of_miles_covered_as_business_trips = (11487.0)/(12204.7)
print('Proportion of miles covered as business trips: ',Proportion_of_miles_covered_as_business_trips)

print('______________________')

#Proportion of miles covered as personal trips= (Total Miles clocked as Personal Trips)/ (Total Miles)

Proportion_of_miles_covered_as_personal_trips = (717.7)/(12204.7)
print('Proportion of miles covered as personal trips: ',Proportion_of_miles_covered_as_personal_trips)
